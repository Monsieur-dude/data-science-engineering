# %%
user = input()

if int(user) % 2 == 0 :
    print('짝수')
else :
    print('홀수')
# Out:
# 30
# 짝수

# %%
user = input()
if int(user) + 20 > 255 :
    print('output :', 255)
else :
    print('output :', int(user) + 20)
# Out:
# 170
# output : 190

# %%
user = input('input :')

if int(user) - 20 < 0 :
    print('output :', 0)
elif int(user) - 20 > 255 :
    print('output :', 22755)
else :
    print('output :', int(user) - 20 )
# Out:
# input :276
# output : 255

# %%
user = input()

if user[-2:] == "00" :
    print('a punto!')
else :
    print('it is not a punto!')
# Out:
# 2300
# a punto!

# %%
'2300'[-2:]
# Out:
# '00'

# %%
fruit = ['apple', 'peach', 'pear']
user = input('favorite fruit? :')
if user in fruit :
    print("that's correct!")
else :
    print("that's not correct!")
# Out:
# favorite fruit? :pear
# that's correct!

# %%
warn_investment_list = ['ms', 'google', 'naver', 'kakao', 'samsung', 'lg']
user = input()

if user in warn_investment_list :
    print("risky move!")
else :
    print("not risky move!")
# Out:
# apple
# not risky move!

# %%
fruit = {"spring":"strawberry", "summer": "tomato", "fall": "apple"}

user = input("my favorite season is :")

if user in fruit.keys() :
    print("that's correct!")
else :
    print("that's not correct!")
# Out:
# my favorite season is :winter
# that's not correct!

# %%
user = input()

if user.islower() == True :
    print(user.upper())
else :
    print(user.lower())
# Out:
# C
# c

# %%
user = input()

if 81 < int(user) < 100 :
    print("A")
elif 61 < int(user) < 80 :
    print("B")
elif 41 < int(user) < 60 :
    print("C")
elif 21 < int(user) < 40 :
    print("D")
# Out:
# 105

# %%
dict_currency = {"dollar" : 1167, "Yen" : 1.096, "Euro" : 1268, "CNY" : 171}
user = input()
user_money = float(user.split(' ')[0])


if "dollar" in user :
    print(user_money * dict_currency["dollar"], "won")
elif "Yen" in user :
    print(user_money * dict_currency1["Yen"], "won")
elif "Euro" in user :
    print(user_money * dict_currency["Euro"], "won")
elif "CNY" in user :
    print(user_money * dict_currency["CNY"], "won")
# Out:
# 300

# %%
dict_currency = {"dollar" : 1167, "Yen" : 1.096, "Euro" : 1268, "CNY" : 171}
user = input()
num, currency = user.split()

print(float(num) * dict_currency[currency])
# Out:
# 1000 Euro
# 1268000.0

# %%
user1 = input()
user2 = input()
user3 = input()

if int(user1) > int(user2) :
    if int(user1) > int(user3) :
        print(int(user1))
    else :
        print(int(user3))
elif int(user1) < int(user2) :
    if int(user2) < int(user3) :
        print(int(user3))
    else :
        print(int(user2))
# Out:
# 5
# 8
# 7
# 8

# %%
user1 = input()
user2 = input()
user3 = input()

if int(user1) >= int(user2) and int(user1) >= int(user3) :
    print(int(user1))
elif int(user1) <= int(user2) and int(user3) <= int(user2) :
    print(int(user2))
else :
    print(int(user3))
# Out:
# 10
# 7
# 5
# 10

# %%
dict_tele = {'011' : 'SKT', '016': 'KT', '019' : 'LGU', '010' : 'Unknown'}

user = input('your phone number? :')
user_company = user.split('-')[0]


print('You are using ', dict_tele[user_company], 'Broadcom.')
# Out:
# your phone number? :011-6060-9999
# You are using  SKT Broadcom.

# %%
user = input('Postal code: ')
postal_town = user[:3]

if postal_town in ['010', '011', '012'] :
    print('강북구')
elif postal_town in ['013', '014', '015'] :
    print('도봉구')
else :
    print('노원구')
# Out:
# Postal code: 01053
# 강북구

# %%
user = input("주민등록번호 :")
user_birth, user_gender = user.split('-')

if user_gender[1] == 1 or 3:
    print("Male")
elif user_gender[1] == 2 or 4:
    print("Female")
# Out:
# 주민등록번호 :910218-1483916
# Male

# %%
user = input("주민등록번호 :")
user_birth, user_gender = user.split('-')

list_seoul = ['00', '01', '02', '03', '04', '05', '06', '07', '08']
list_busan = ['09', '10', '11', '12']

if user_gender[1:3] in list_seoul :
    print("local code:", user_gender[1:3], "you are born in seoul")
else :
    print("local code:", user_gender[1:3], "you are not born in seoul")
# Out:
# 주민등록번호 :910218-1090000
# local code: 09 you are not born in seoul

# %%
user = input("주민등록번호 :")
user_birth, user_gender = user.split('-')
user_nums = user_birth + user_gender
# Out:
# 주민등록번호 :950101-1234567
# 9501011234567

# %%
user = input("주민등록번호 :")
user_birth, user_gender = user.split('-')
user_nums = user_birth + user_gender

sum = int(user_nums[0])*2 + int(user_nums[1])*3 + int(user_nums[2])*4 + int(user_nums[3])*5 + int(user_nums[4])*6 + int(user_nums[5])*7 + int(user_nums[6])*8 + int(user_nums[7])*9 + int(user_nums[8])*2 + int(user_nums[9])*3 + int(user_nums[10])*4 + int(user_nums[11])*5
user_13rd = 11 - (sum % 11)

if user[-1] == str(user_13rd) :
    print(int(sum), "유효한 주민등록번호입니다.")
else :
    print(int(sum), "유효하지 않습니다.")
# Out:
# 주민등록번호 :950505-1023536
# 149 유효하지 않습니다.

# %%
import requests
btc = requests.get("https://api.bithumb.com/public/ticker/").json()['data']

price_maxAndmin = int(btc['max_price']) - int(btc ['min_price'])

if int(btc['opening_price']) + price_maxAndmin > int(btc['max_price']) :
    print("변동폭은 ", price_maxAndmin, "상승장")
else :
    print("변동폭은 ", price_maxAndmin, "하락장")
# Out:
# 변동폭은  6027000 상승장
