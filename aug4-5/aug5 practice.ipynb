# %%
class Human() :
    
    def __init__(self) :
        
        print("응애응애")

areum = Human()
# Out:
# 응애응애

# %%
class Human() :
    def __init__(self, name, age, gender) :
        self.name = name
        self.age = age
        self.gender = gender

areum = Human("Areum", 25, "Female")

print("Name : {0}, Age : {1}, Gender : {2}".format(areum.name, areum.age, areum.gender))
# Out:
# Name : Areum, Age : 25, Gender : Female

# %%
class Human() :
    def __init__(self, name, age, gender) :
        self.name = name
        self.age = age
        self.gender = gender
    def __del__(self) :
        print("Don't let the know my death")
    def who(self) :
        print("Name : {0}, Age : {1}, Gender : {2}".format(self.name, self.age, self.gender))
    def setInfo(self, name, age, gender) :
        self.name = name
        self.age = age
        self.gener = gender

areum = Human("??", 25, "??")
areum.who()
areum.setInfo("Areum", 25, "Female")
areum.who()
# Out:
# Name : ??, Age : 25, Gender : ??
# Name : Areum, Age : 25, Gender : ??

# %%
class Stock() :
    def __init__(self, name, code, per, pbr, dividend) :
        self.name = name
        self.code = code
        self.per = per
        self.pbr = pbr
        self.dividend = dividend
    def set_name(self, name) :
        self.name = name
        print(name)
    def set_code(self, code) :
        self.code = code
    def set_per(self, per) :
        self.per = per
    def set_pbr(self, pbr) :
        self.pbr = pbr
    def set_dividend(self, dividend) :
        self.dividend = dividend

    def get_name(self) :
        return self.codeName
    
    def get_code(self) :
        return self.codeNum

Samsung = Stock("Samsung Electronics", "005930", 15.79, 1.33, 2.83)
Samsung.set_per(12.75)

# %%
Hyundai = Stock("Hyundai", "005380", 8.70, 0.35, 4.27)
LG = Stock("LG Electronics", '066570', 317.34, 0.69, 1.37)

Samsung.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-b0889b818901> in <module>()
#       2 LG = Stock("LG Electronics", '066570', 317.34, 0.69, 1.37)
#       3
# ----> 4 Samsung.Stock()
#
# AttributeError: 'Stock' object has no attribute 'Stock'
